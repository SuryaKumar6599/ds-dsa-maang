# %%
from unittest import case
import pandas as pd
import logging as logger

# %%
#1. Basic error handling for file reading
try:
    df = pd.read_csv("data.csv")
except FileNotFoundError:
    logger.error("Dataset not found")
except pd.errors.EmptyDataError:
    logger.warning("Empty dataset")
except UnicodeDecodeError:
    logger.error("Encoding issue in dataset")
# Out:
# ERROR:root:Dataset not found

# %%
#2. Model Layer Exceptions
class ValidationError(Exception):
    pass

def validate_ic_sr(case):
    if "patient_age" not in case:
        raise ValidationError("Missing patient_age")
    
try:
    validate_ic_sr(case)
except ValidationError as e:
    logger.warning(f"Validation failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7         raise ValidationError("Missing patient_age")
#       9 try:
# ---> 10     validate_ic_sr(case)
#      11 except ValidationError as e:
#      12     logger.warning(f"Validation failed: {e}")
#
# Cell In[3], line 6, in validate_ic_sr(case)
#       5 def validate_ic_sr(case):
# ----> 6     if "patient_age" not in case:
#       7         raise ValidationError("Missing patient_age")
#
# TypeError: argument of type 'module' is not a container or iterable

# %%
 
# %pip install joblib

import joblib
 
#3. Controller Layer Exceptions
try:
    model = joblib.load("model.pkl")
except FileNotFoundError:
    logger.error("Model file missing")
except Exception as e:
    logger.critical(f"Model loading failed: {e}")
# Out:
# Collecting joblib
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.5.3
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:Model file missing

# %%
#4. API Layer Exceptions
import requests

try:
    response = requests.get(url, timeout=5)
    response.raise_for_status()
except requests.exceptions.Timeout:
    logger.error("API timeout")
except requests.exceptions.HTTPError as e:
    logger.error(f"HTTP error: {e}")
except requests.exceptions.RequestException:
    logger.error("General API failure")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 import requests
#       4 try:
# ----> 5     response = requests.get(url, timeout=5)
#       6     response.raise_for_status()
#       7 except requests.exceptions.Timeout:
#
# NameError: name 'url' is not defined

# %%
#5. Deployment Layer Exceptions
try:
    doc = nlp(text)
except ValueError:
    logger.error("Invalid text input")
except RuntimeError:
    logger.error("spaCy pipeline crashed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #5. Deployment Layer Exceptions
#       2 try:
# ----> 3     doc = nlp(text)
#       4 except ValueError:
#       5     logger.error("Invalid text input")
#
# NameError: name 'nlp' is not defined

# %%
#6. Logging and Monitoring Exceptions
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

try:
    engine = create_engine('sqlite:///:memory:')  # Example database; adjust as needed
    Session = sessionmaker(bind=engine)
    session = Session()

    session.commit()
except SQLAlchemyError as e:
    session.rollback()
    logger.error(f"DB error: {e}")
